# %% [markdown]
# Name: Shreyas Dongre
# Roll no: 082
# Stream: CS (AI)
# Division: I
# Semester: 4th Semester
# Batch: I-3
#                                                                        Date: 4/3/2022
# Subject: ML
# ###Experiment-10

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
import math
import seaborn as sns
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df=pd.read_csv("test_knn.csv")

# %%
df.shape
# Out:
# (10, 3)

# %%
df.head()
# Out:
#           a         b  c
# 0  2.781084  2.550537  0
# 1  1.465489  2.362125  0
# 2  3.396562  4.400294  0
# 3  1.388070  1.850220  0
# 4  3.064072  3.005306  0

# %%
def euclidean_dist(x1, y1, x2, y2):
    return np.sqrt(np.power((x1-x2), 2) + np.power((y1-y2), 2))

X = df[['a', 'b']]
Y = df['c']

# %%
def knn_test_point(x, y, k, base_X, base_Y):
    dist_mat = list()
    for name, i in enumerate(zip(base_X.iloc[:, 0], base_X.iloc[:, 1])):
        dist_mat.append((name, euclidean_dist(x, y, i[0], i[1])))
    dist_mat.sort(key=lambda x:x[1])
    
    res = list()
    for i in range(k):
        res.append(base_Y[dist_mat[i][0]])

    pred = max(set(res), key=res.count)
    return pred

# %%
def test(k, base_x, base_y):
    pred_res = list()
    for i,j in zip(base_x.iloc[:, 0], base_x.iloc[:, 1]):
        pred_res.append(knn_test_point(i, j, k, base_x, base_y))
    return pred_res
yhat=test(3, X, Y)

# %%
from sklearn.metrics import confusion_matrix
res = confusion_matrix(Y,yhat)
print(res)
# Out:
# [[5 0]
#  [0 5]]

# %%
sns.heatmap(res, annot=True)
plt.show()

# %%
from sklearn.metrics import precision_score,recall_score
precision_score(Y,yhat)
# Out:
# 1.0

# %%
recall_score(Y,yhat)
# Out:
# 1.0

# %%
from sklearn.metrics import f1_score
f1_score(Y,yhat)
# Out:
# 1.0

# %% [markdown]
# #Conclusion
# 1) KNN is used for classification and regression.
# 2) In K-NN  classification  the function is only approximated locally and all computation is deferred until function evaluation.
# 3) Both for classification and regression, a useful technique can be to assign weights to the contributions of the neighbors, so that the nearer neighbors contribute more to the average than the more distant ones.

# %%
! jupyter nbconvert --to html I082_Shreyas_Dongre_ML_Prac10.ipynb
# Out:
# [NbConvertApp] Converting notebook I082_Shreyas_Dongre_ML_Prac10.ipynb to html
# [NbConvertApp] Writing 295697 bytes to I082_Shreyas_Dongre_ML_Prac10.html
