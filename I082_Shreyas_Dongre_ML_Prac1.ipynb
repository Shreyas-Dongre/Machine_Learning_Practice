# %% [markdown]
# Name: Shreyas Dongre
# Roll no: 082
# Stream: CS (AI)
# Division: I
# Semester: 4th Semester
# Batch: I-3
#                                                                        Date: 13/12/2021
#
# ###Experiment-1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv('Iris.csv')  #read the imported file as a data frame

# %%
df.head()    #reading the starting values of the dataset.
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.describe()  #stats of a particular dataset
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# ###Preprocessing the Data Set:

# %%
#seperating features and labels(species)
features=df.iloc[:,:-1].values  #iloc needs index of the col.: says abt the rows.
species=df.loc[:,"Species"]    #loc needs name of col

# %%
features
# Out:
# array([[1.00e+00, 5.10e+00, 3.50e+00, 1.40e+00, 2.00e-01],
#        [2.00e+00, 4.90e+00, 3.00e+00, 1.40e+00, 2.00e-01],
#        [3.00e+00, 4.70e+00, 3.20e+00, 1.30e+00, 2.00e-01],
#        [4.00e+00, 4.60e+00, 3.10e+00, 1.50e+00, 2.00e-01],
#        [5.00e+00, 5.00e+00, 3.60e+00, 1.40e+00, 2.00e-01],
#        [6.00e+00, 5.40e+00, 3.90e+00, 1.70e+00, 4.00e-01],
#        [7.00e+00, 4.60e+00, 3.40e+00, 1.40e+00, 3.00e-01],
#        [8.00e+00, 5.00e+00, 3.40e+00, 1.50e+00, 2.00e-01],
#        [9.00e+00, 4.40e+00, 2.90e+00, 1.40e+00, 2.00e-01],
#        [1.00e+01, 4.90e+00, 3.10e+00, 1.50e+00, 1.00e-01],
#        [1.10e+01, 5.40e+00, 3.70e+00, 1.50e+00, 2.00e-01],
#        [1.20e+01, 4.80e+00, 3.40e+00, 1.60e+00, 2.00e-01],
#        [1.30e+01, 4.80e+00, 3.00e+00, 1.40e+00, 1.00e-01],
#        [1.40e+01, 4.30e+00, 3.00e+00, 1.10e+00, 1.00e-01],
#        [1.50e+01, 5.80e+00, 4.00e+00, 1.20e+00, 2.00e-01],
#        [1.60e+01, 5.70e+00, 4.40e+00, 1.50e+00, 4.00e-01],
# ...

# %%
species
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
#to figure out any missing values in features
df=df.dropna()  #to delete null values

# %%
df.shape #since there are no missing values,shape remains same.
# Out:
# (150, 6)

# %%
#plot scatterplot of the features:
plt.scatter(df['SepalLengthCm'],df['SepalWidthCm'])

# %%
plt.scatter(df['PetalLengthCm'],df['PetalWidthCm'])

# %%
#Scaling the features
features=df.iloc[:,:-1]
scaler = StandardScaler()  
#StandardScaler follows Standard Normal Distribution (SND). 
#Therefore, it makes mean = 0 and scales the data to unit variance. 

scaler.fit(features) 
# Fit calculates the parameters or weights on the data.

features = scaler.transform(features) 
# transform is transforming all the features using respective mean and variance.

features
# Out:
# array([[-1.72054204e+00, -9.00681170e-01,  1.03205722e+00,
#         -1.34127240e+00, -1.31297673e+00],
#        [-1.69744751e+00, -1.14301691e+00, -1.24957601e-01,
#         -1.34127240e+00, -1.31297673e+00],
#        [-1.67435299e+00, -1.38535265e+00,  3.37848329e-01,
#         -1.39813811e+00, -1.31297673e+00],
#        [-1.65125846e+00, -1.50652052e+00,  1.06445364e-01,
#         -1.28440670e+00, -1.31297673e+00],
#        [-1.62816394e+00, -1.02184904e+00,  1.26346019e+00,
#         -1.34127240e+00, -1.31297673e+00],
#        [-1.60506942e+00, -5.37177559e-01,  1.95766909e+00,
#         -1.17067529e+00, -1.05003079e+00],
#        [-1.58197489e+00, -1.50652052e+00,  8.00654259e-01,
#         -1.34127240e+00, -1.18150376e+00],
#        [-1.55888037e+00, -1.02184904e+00,  8.00654259e-01,
#         -1.28440670e+00, -1.31297673e+00],
#        [-1.53578584e+00, -1.74885626e+00, -3.56360566e-01,
#         -1.34127240e+00, -1.31297673e+00],
# ...

# %%
! jupyter nbconvert --to html I082_Shreyas_Dongre_ML_Prac1.ipynb
# Out:
# [NbConvertApp] Converting notebook I082_Shreyas_Dongre_ML_Prac1.ipynb to html
# [NbConvertApp] Writing 328957 bytes to I082_Shreyas_Dongre_ML_Prac1.html
